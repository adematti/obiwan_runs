# %%
import os
import logging
import numpy as np
from matplotlib import pyplot as plt
from paths import *
from photometry import *

logger = logging.getLogger('EBV1000')
setup_logging()

run = 'north'
#run = 'south'
region = run[0].upper()
path_data = path_data(region)
path_randoms = path_randoms(region)
path_mctool = path_mctool(region)
path_obiwan = os.path.join(path_dir,'Obiwan','dr9','ebv1000',run,'merged','matched_input.fits')

# %%
def isELG_colors(gflux=None, rflux=None, zflux=None, south=True, gmarg=0., grmarg=0., rzmarg=0., primary=None):
    """
    Apply ELG selection with box enlarged by ``gmarg``, ``grmarg``, ``rzmarg``.

    Base selection from https://github.com/desihub/desitarget/blob/master/py/desitarget/cuts.py.
    """
    #print(gmarg,grmarg,rzmarg)
    if primary is None:
        primary = np.ones_like(rflux, dtype='?')
    elg = primary.copy()

    # ADM work in magnitudes instead of fluxes. NOTE THIS IS ONLY OK AS
    # ADM the snr masking in ALL OF g, r AND z ENSURES positive fluxes.
    g = 22.5 - 2.5*np.log10(gflux.clip(1e-16))
    r = 22.5 - 2.5*np.log10(rflux.clip(1e-16))
    z = 22.5 - 2.5*np.log10(zflux.clip(1e-16))

    # ADM cuts shared by the northern and southern selections.
    elg &= g > 20 - gmarg                          # bright cut.
    elg &= r - z > 0.3 - rzmarg                    # blue cut.
    elg &= r - z < 1.6 + rzmarg                    # red cut.
    elg &= g - r < -1.2*(r - z) + 1.6 + grmarg     # OII flux cut.

    # ADM cuts that are unique to the north or south.
    if south:
        elg &= g < 23.4 + gmarg # faint cut.
        # ADM south has the FDR cut to remove stars and low-z galaxies.
        elg &= g - r < 1.15*(r - z) - 0.15 + grmarg
    else:
        elg &= g < 23.5 + gmarg # faint cut.
        elg &= g - r < 1.15*(r - z) - 0.20 + grmarg # remove stars and low-z galaxies.

    return elg

def mask_ts(self,key_flux='EFLUX',region=region,gmarg=0.,grmarg=0.,rzmarg=0.,gcut=-np.inf):
    mask = isELG_colors(gflux=self['{}_G'.format(key_flux)],rflux=self['{}_R'.format(key_flux)],
                        zflux=self['{}_Z'.format(key_flux)],south=region=='S',
                        gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg)
    mask &= self['{}_G'.format(key_flux)] > gcut
    return mask

TargetSelection.mask_ts = mask_ts

# %% [markdown]
# # Let's first compare Obiwan to ELG targets, when applying TS

# %%
# Obiwan
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
#obiwan['MATCHED'] = obiwan['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(obiwan['MATCHED'].sum(),obiwan.size))
obiwan.set_estimated_flux(key='INPUT_EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask_tsin = obiwan.mask_maskbit(key_nobs='INPUT_NOBS',key_maskbits='INPUT_MASKBITS') & obiwan.mask_ts(key_flux='INPUT_EFLUX',region=region)
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan.mask_ts(key_flux='EFLUX',region=region) & obiwan['MATCHED']
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
obiwan_data = obiwan[mask_tsout]
obiwan_randoms = obiwan[mask_tsin]
# Out:
# [ 000000.06 ]: 01-01 21:23  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000000.61 ]: 01-01 21:23  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000001.97 ]: 01-01 21:23  EBV1000         INFO     Found 117676/122881 matches.
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in greater
# [ 000002.35 ]: 01-01 21:23  EBV1000         INFO     Selecting 17044 (output)/15046 (input) injected sources.

# %%
# ELG targets, TS applied already
bricknames = np.unique(obiwan['BRICKNAME'])
data = TargetSelection.load_objects(path_data,region=region)
mask = np.in1d(data['BRICKNAME'],bricknames)
mask[:] = True # do not cut data on the same bricks as Obiwan
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
data.set_mag_from_flux(key_flux='EFLUX')
mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & data.mask_ts(key_flux='EFLUX',region=region)
logger.info('Selecting {:d} targets.'.format(mask.sum()))
data = data[mask]

randoms = TargetSelection.load_objects(path_randoms,region=region)
mask = np.in1d(randoms['BRICKNAME'],bricknames)
mask[:] = True
mask &= randoms.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
randoms = randoms[mask]

def from_map(cat,fields):
    import healpy as hp
    map = Catalogue.load(path_hp)
    theta,phi = utils.radec_to_thphi(cat['RA'],cat['DEC'])
    hppix = hp.ang2pix(map.header['HPXNSIDE'],theta,phi,nest=map.header['HPXNEST'],lonlat=False)
    for field in fields: cat[field] = map[field][hppix]
# Out:
# [ 000002.70 ]: 01-01 21:23  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/data_N_cut.fits.
# [ 000004.35 ]: 01-01 21:23  TargetSelection INFO     Selecting 3081248/3081248 targets.
# [ 000009.95 ]: 01-01 21:23  EBV1000         INFO     Selecting 2382221 targets.
# [ 000011.21 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/randoms_N_cut.fits.
# [ 000013.91 ]: 01-01 21:24  TargetSelection INFO     Selecting 3222451/3222451 targets.

# %%
# Density maps
map = Catalogue.load(path_hp)
obiwan_dens = HealpixDensity(map=map)
obiwan_dens.set_randoms(randoms=obiwan_randoms)
obiwan_dens.set_properties()
obiwan_dens.set_data(data=obiwan_data)
obiwan_dens.plot_density_map(title='Obiwan density',vmin=0,vmax=2)

obiwan_dens = HealpixDensity(map=map)
#obiwan_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
obiwan_dens.set_randoms(randoms=obiwan_randoms)
obiwan_dens.set_properties()
obiwan_dens.set_data(data=obiwan_data)

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = [obiwan_dens]
labels = ['DR9','Obiwan']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},xedges={'quantiles':[0.02,0.98]})
plt.show()
# Out:
# [ 000025.28 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.
# [ 000025.63 ]: 01-01 21:24  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000025.64 ]: 01-01 21:24  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000025.65 ]: 01-01 21:24  HealpixDensity  INFO     Found 1614 bricks with randoms.
# [ 000026.12 ]: 01-01 21:24  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000026.13 ]: 01-01 21:24  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000026.13 ]: 01-01 21:24  HealpixDensity  INFO     Found 1614 bricks with randoms.
# [ 000026.13 ]: 01-01 21:24  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000026.37 ]: 01-01 21:24  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000026.37 ]: 01-01 21:24  HealpixDensity  INFO     Found 97884 bricks with randoms.
# [ 000026.76 ]: 01-01 21:24  Properties      INFO     Calculating EBV statistics.
# [ 000026.85 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0380.
# [ 000026.86 ]: 01-01 21:24  Properties      INFO     Calculating EBV statistics.
# [ 000026.91 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1255.
# [ 000026.92 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000027.00 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0330.
# [ 000027.01 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000027.05 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.1161.
# [ 000027.06 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000027.15 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0326.
# [ 000027.15 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000027.20 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0895.
# [ 000027.20 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000027.29 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0350.
# [ 000027.29 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000027.34 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0661.
# [ 000027.35 ]: 01-01 21:24  Properties      INFO     Calculating STARDENS statistics.
# [ 000027.43 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0356.
# [ 000027.43 ]: 01-01 21:24  Properties      INFO     Calculating STARDENS statistics.
# [ 000027.48 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0546.
# [ 000027.49 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000027.58 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0363.
# [ 000027.58 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000027.63 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0495.
# [ 000027.63 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000027.73 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0375.
# [ 000027.73 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000027.77 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0502.
# [ 000027.78 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000027.87 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0368.
# [ 000027.87 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000027.91 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0389.

# %% [markdown]
# ## No trend with EBV... Let's focus on EBV

# %%
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
denslow = BinnedDensity(ref=data,fields=['EFLUX_G'],ranges=(0.36,1.5),nbins=10)
denslow.set_randoms(randoms=data)
denslow.set_data(data=data[data['EBV']<0.1])
denslow.set_properties(weights='data')
denshigh = denslow.deepcopy()
denshigh.set_data(data=data[data['EBV']>0.1])
denshigh.set_properties(weights='data')
densratio = denshigh/denslow

obiwan_data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
denslow = BinnedDensity(ref=obiwan_data,fields=['EFLUX_G'],ranges=(0.36,1.5),nbins=10)
denslow.set_randoms(randoms=obiwan_data)
denslow.set_data(data=obiwan_data[obiwan_data['EBV']<0.1])
denslow.set_properties(weights='data')
denshigh = denslow.deepcopy()
denshigh.set_data(data=obiwan_data[obiwan_data['EBV']>0.1])
denshigh.set_properties(weights='data')
obiwan_densratio = denshigh/denslow

labels = ['EBV > 0.1 / EBV < 0.1 DR9','Obiwan']
densratio.plot_density_variations(prop='EFLUX_G',others=[obiwan_densratio],histos=[denslow,denshigh],var_kwargs={'errors':False,'labels':labels},histo_kwargs={'colors':['g']*2})
# Out:
# [ 000029.48 ]: 01-01 21:24  BinnedStatistic INFO     Using 10 bins.
# [ 000029.58 ]: 01-01 21:24  BinnedDensity   INFO     Inferring brickid from randoms.
# [ 000029.59 ]: 01-01 21:24  BinnedDensity   INFO     Found 10 bricks with randoms.
# [ 000030.38 ]: 01-01 21:24  BinnedStatistic INFO     Using 10 bins.
# [ 000030.38 ]: 01-01 21:24  BinnedDensity   INFO     Inferring brickid from randoms.
# [ 000030.38 ]: 01-01 21:24  BinnedDensity   INFO     Found 10 bricks with randoms.
# [ 000030.43 ]: 01-01 21:24  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000030.52 ]: 01-01 21:24  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000030.52 ]: 01-01 21:24  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000030.53 ]: 01-01 21:24  BinnedDensity   INFO     Fraction of randoms not included in EFLUX_G plot: 0.0000.
# [ 000030.53 ]: 01-01 21:24  Properties      INFO     Calculating EFLUX_G statistics.
# [ 000030.53 ]: 01-01 21:24  BinnedDensity   INFO     Fraction of randoms not included in EFLUX_G plot: 0.0000.

# %% [markdown]
# # Redo without TS cuts (more stats)

# %%
# Obiwan
obiwan.set_estimated_flux(key='INPUT_EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask_tsin = obiwan.mask_maskbit(key_nobs='INPUT_NOBS',key_maskbits='INPUT_MASKBITS')
#mask_tsin[:] = True
for b in obiwan.bands: obiwan[b] = obiwan.mag_from_flux(b,key_flux='EFLUX')
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan['MATCHED']
#mask_tsout = obiwan['MATCHED']
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
obiwan_data = obiwan[mask_tsout]
obiwan_randoms = obiwan[mask_tsin]
# Out:
# /home/adematti/Bureau/DESI/NERSC/lib/photometry/utils/utils.py:21: RuntimeWarning: divide by zero encountered in log10
#   return -2.5*(np.log10(x)-9.)
# /home/adematti/Bureau/DESI/NERSC/lib/photometry/utils/utils.py:21: RuntimeWarning: invalid value encountered in log10
#   return -2.5*(np.log10(x)-9.)
# [ 000030.76 ]: 01-01 21:24  EBV1000         INFO     Selecting 109937 (output)/112464 (input) injected sources.

# %%
# Density maps
obiwan_dens = HealpixDensity(map=map)
#obiwan_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
obiwan_dens.set_randoms(randoms=obiwan_randoms)
obiwan_dens.set_properties()
obiwan_dens.set_data(data=obiwan_data)

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = []
labels = ['Obiwan']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    obiwan_dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},xedges={'quantiles':[0.1,0.95]})
    
plt.show()
# Out:
# [ 000031.09 ]: 01-01 21:24  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000031.10 ]: 01-01 21:24  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000031.10 ]: 01-01 21:24  HealpixDensity  INFO     Found 1896 bricks with randoms.
# [ 000031.22 ]: 01-01 21:24  Properties      INFO     Calculating EBV statistics.
# [ 000031.28 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1449.
# [ 000031.29 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000031.34 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.1539.
# [ 000031.35 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000031.41 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.1524.
# [ 000031.41 ]: 01-01 21:24  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000031.47 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.1486.
# [ 000031.48 ]: 01-01 21:24  Properties      INFO     Calculating STARDENS statistics.
# [ 000031.53 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.1413.
# [ 000031.53 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000031.59 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.1554.
# [ 000031.59 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000031.65 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.1544.
# [ 000031.65 ]: 01-01 21:24  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000031.71 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.1541.

# %% [markdown]
# ## Very small trend (2% between 0.02 and 0.15) with EBV

# %% [markdown]
# # Next, look at flux bias and variance as a function of EBV

# %%
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
obiwan = obiwan[obiwan['MATCHED']]

from scipy import special,stats
def estimate_std(tab):
    # trick to estimate standard deviation in presence of outliers
    return np.median(np.abs(tab-np.median(tab)))/(2.**0.5*special.erfinv(1./2.))
from photometry.utils import Binning

from_map(obiwan,fields=['STARDENS'])

#fields = ['EBV'] + ['PSFSIZE_G','PSFSIZE_R','PSFSIZE_Z']
fields = ['EBV'] + ['PSFDEPTH_G','PSFDEPTH_R','PSFDEPTH_Z']

for xlabel in fields:
    fig,lax = plt.subplots(ncols=3,nrows=2,sharex=False,sharey=False,figsize=(16,6))
    fig.subplots_adjust(hspace=0.4,wspace=0.4)
    lax = lax.flatten()
    bands = ['G','R','Z']
    for ax,b in zip(lax,bands):
        obiwan['DELTA_FLUX_{}'.format(b)] = (obiwan['FLUX_{}'.format(b)]-obiwan['INPUT_FLUX_{}'.format(b)]) #/obiwan['MW_TRANSMISSION_{}'.format(b)]
        obiwan.plot_scatter(ax,prop1=xlabel,prop2='DELTA_FLUX_{}'.format(b),xedges={'quantiles':[0.01,0.99]},yedges={'quantiles':[0.01,0.99]})
        ax.axhline(y=0,xmin=0,xmax=1,color='r')
    lax = lax[len(bands):]
    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        y = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_FLUX_{}'.format(b)],bins=xedges,statistic='median')[0]
        yerr = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_FLUX_{}'.format(b)],bins=xedges,statistic=estimate_std)[0]
        counts = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_FLUX_{}'.format(b)],bins=xedges,statistic='count')[0]
        yerr *= 1/counts**0.5
        ax.errorbar(x,y,yerr)
        ax.axhline(y=0,xmin=0,xmax=1,color='r')
        ax.set_ylabel('DELTA_FLUX_{}'.format(b))
        ax.set_xlabel(xlabel)
    plt.show()
# Out:
# [ 000032.57 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000033.05 ]: 01-01 21:24  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000034.30 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.

# %% [markdown]
# ## Maybe small trend of DELTA_FLUX_G,R with EBV? (actually most of the trends are due to dividing by transmission). Let's look at magnitudes, maybe something will show up

# %%
for xlabel in ['EBV']:
    fig,lax = plt.subplots(ncols=5,nrows=2,sharex=False,sharey=False,figsize=(20,6))
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    bands = ['G','R','Z'] + ['GR','RZ']
    for ax,b in zip(lax,bands):
        if b == 'GR':
            obiwan['DELTA_{}'.format(b)] = obiwan['DELTA_G'] - obiwan['DELTA_R']
        elif b == 'RZ':
            obiwan['DELTA_{}'.format(b)] = obiwan['DELTA_R'] - obiwan['DELTA_Z']
        else:
            obiwan['DELTA_{}'.format(b)] = utils.flux_to_mag(obiwan['FLUX_{}'.format(b)].clip(1e-16)/obiwan['MW_TRANSMISSION_{}'.format(b)])
            obiwan['DELTA_{}'.format(b)] -= utils.flux_to_mag(obiwan['INPUT_FLUX_{}'.format(b)].clip(1e-16)/obiwan['INPUT_MW_TRANSMISSION_{}'.format(b)])
            #obiwan['DELTA_{}'.format(b)] = utils.flux_to_mag(obiwan['FLUX_{}'.format(b)].clip(1e-16))
            #obiwan['DELTA_{}'.format(b)] -= utils.flux_to_mag(obiwan['INPUT_FLUX_{}'.format(b)].clip(1e-16))
        obiwan.plot_scatter(ax,prop1=xlabel,prop2='DELTA_{}'.format(b),xedges={'quantiles':[0.01,0.99]},yedges={'quantiles':[0.01,0.99]})
        ax.axhline(y=0,xmin=0,xmax=1,color='r')
    lax = lax[len(bands):]

    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        y = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_{}'.format(b)],bins=xedges,statistic='median')[0]
        yerr = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_{}'.format(b)],bins=xedges,statistic=estimate_std)[0]
        counts = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_{}'.format(b)],bins=xedges,statistic='count')[0]
        yerr *= 1/counts**0.5
        ax.errorbar(x,y,yerr)
        ax.axhline(y=0,xmin=0,xmax=1,color='r')
        ax.set_ylabel('DELTA_{}'.format(b))
        ax.set_xlabel(xlabel)
    plt.show()

# %% [markdown]
# ## Again, nothing striking. Let's reproduce what Ashley found with MCTool

# %%
fig,ax = plt.subplots(ncols=1,nrows=1,sharex=False,sharey=False,figsize=(6,6))
dens.plot_density_variations(ax=ax,others=[],prop='EBV',histos=[dens],var_kwargs={'labels':'DR9'},leg_kwargs={},xedges={'quantiles':[0.1,0.9]})
ebv = np.linspace(*ax.get_xlim(),num=10)
model = 1. - .25/.15*ebv # Ashley's fit
norm = 1.04 # just for plotting purposes
model = model/np.mean(model)/norm - 1.

truth = TargetSelection.load_objects(path_truth,tracer='ELG',region=None,case_sensitive=False)
truth.set_flux_from_mag(key='FLUX')
truth['REDSHIFT'] = truth['hsc_mizuki_photoz_best']
truth.region = region
mask = np.all([~np.isnan(truth[b]) for b in truth.bands],axis=0)
truth = truth[mask]

# Ashley's prediction, see: https://github.com/desihub/LSS/blob/master/Sandbox/imaging/ELGEBV.ipynb
def predict_additional_transmission(ebv,flux,b):
    transmission = 10.**(-0.4*0.6*TargetSelection.EXT_COEFFS[b]*ebv)
    return transmission + (1.-transmission)*special.erf(2.*flux)

correlation = np.ones((3,3))*.5 #just given them all correlation of 0.5 for now
np.fill_diagonal(correlation,1.)
std = np.array([0.03,0.05,0.1])
flux_covariance = correlation*std*std[:,None]
efficiency = []
for ebv_ in ebv:
    mc = MCTool(truth=truth,seed=42)
    mc.set_sel_params(sn_band_min=6,sn_flat_min=None,sn_red_min=None)
    mc.set_sim_params(flux_covariance=flux_covariance,flux_adbias=0.,flux_mulbias=1.)
    mc.sim['EBV'] = ebv_
    mc.sim.set_estimated_transmission(key='EMW_TRANSMISSION')
    mc.sim.set_estimated_transmission(key='MW_TRANSMISSION')
    mc.sim['MW_TRANSMISSION_G'] *= predict_additional_transmission(ebv=mc.sim['EBV'],flux=mc.truth['FLUX_G'],b='G')
    #for b in mc.sim.bands:
    #    mc.sim['MW_TRANSMISSION_{}'.format(b)] *= 10**(-0.4*0.25*mc.sim.EXT_COEFFS[b]*mc.sim['EBV'])
    mc()
    efficiency.append(mc.get_efficiency())
efficiency = np.array(efficiency)/np.mean(efficiency)/norm - 1.

ax.plot(ebv,model,label='empirical fit',color='k')
ax.plot(ebv,efficiency,label='MC prediction',color='r')
ax.legend()
plt.show()
# Out:
# [ 000047.93 ]: 01-01 21:24  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1960.
# [ 000047.94 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/desi_mcsyst_truth.dr7.34ra38.-7dec-3.fits.
# [ 000048.10 ]: 01-01 21:24  TargetSelection INFO     Selecting 549181/549181 targets.

# %% [markdown]
# ## Let's compare Ashley's predicted flux multiplicative bias (EBV, FLUX_G) with Obiwan measurements

# %%
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
obiwan = obiwan[obiwan['MATCHED']]

from mpl_toolkits.axes_grid1 import make_axes_locatable

obiwan.set_estimated_flux(key='INPUT_EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
for xlabel in ['EBV']:
    fig,lax = plt.subplots(ncols=3,nrows=3,sharex=False,sharey=False,figsize=(16,10))
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    bands = ['G','R','Z']
    for ax,b in zip(lax,bands):
        #obiwan['BIAS_FLUX_{}'.format(b)] = obiwan['EFLUX_{}'.format(b)]/obiwan['INPUT_EFLUX_{}'.format(b)]-1.
        obiwan['BIAS_FLUX_{}'.format(b)] = obiwan['EFLUX_{}'.format(b)]-obiwan['INPUT_EFLUX_{}'.format(b)]
        obiwan.plot_scatter(ax,prop1=xlabel,prop2='EFLUX_{}'.format(b),propc='BIAS_FLUX_{}'.format(b),vmin=0.,vmax=0.2,clabel='BIAS_FLUX_{}'.format(b),xedges={'quantiles':[0.01,0.99]},yedges={'quantiles':[0.01,0.99]})
    lax = lax[len(bands):]
    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        yedges = Binning(samples=obiwan['EFLUX_{}'.format(b)],range=[0.01,0.6]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        y = (yedges[:-1] + yedges[1:])/2.
        values = obiwan['BIAS_FLUX_{}'.format(b)]
        z = stats.binned_statistic_2d(obiwan[xlabel],obiwan['EFLUX_{}'.format(b)],values=values,bins=[xedges,yedges],statistic='median')[0]
        im = ax.pcolormesh(x,y,z.T)
        ax.set_ylabel('EFLUX_{}'.format(b))
        ax.set_xlabel(xlabel)
        divider = make_axes_locatable(ax)
        cax = divider.append_axes('right',size='5%',pad=0.05)
        cbar = plt.colorbar(im,cax=cax)
        cbar.set_label('BIAS_FLUX_{}'.format(b),rotation=90)
        ax.set_title('Binned version of the above')
    
    lax = lax[len(bands):]
    def predict_additional_transmission(ebv,eflux,b):
        transmission = 10.**(-0.4*0.6*TargetSelection.EXT_COEFFS[b]*ebv)
        return transmission + (1.-transmission)*special.erf(2.*eflux)
    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        yedges = Binning(samples=obiwan['EFLUX_{}'.format(b)],range=[0.01,0.6]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        y = (yedges[:-1] + yedges[1:])/2.
        #values = obiwan['EFLUX_{}'.format(b)]/obiwan['INPUT_EFLUX_{}'.format(b)]/predict_additional_transmission(obiwan['EBV'],obiwan['INPUT_EFLUX_{}'.format(b)],b)-1.
        values = obiwan['EFLUX_{}'.format(b)]/predict_additional_transmission(obiwan['EBV'],obiwan['INPUT_EFLUX_{}'.format(b)],b)-obiwan['INPUT_EFLUX_{}'.format(b)]
        z = stats.binned_statistic_2d(obiwan[xlabel],obiwan['EFLUX_{}'.format(b)],values=values,bins=[xedges,yedges],statistic='median')[0]
        im = ax.pcolormesh(x,y,z.T)
        ax.set_ylabel('EFLUX_{}'.format(b))
        ax.set_xlabel(xlabel)
        divider = make_axes_locatable(ax)
        cax = divider.append_axes('right',size='5%',pad=0.05)
        cbar = plt.colorbar(im,cax=cax)
        cbar.set_label('BIAS_FLUX_{}'.format(b),rotation=90)
        ax.set_title('Dividing by prediction')
    
    plt.show()
# Out:
# [ 000050.41 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000050.54 ]: 01-01 21:24  TargetSelection INFO     Selecting 122881/122881 targets.

# %% [markdown]
# ## More BIAS_FLUX_G variations after dividing by prediction: Obiwan measurements look opposite to Ashley's prediction :(

# %% [markdown]
# ## Miscellaneous

# %%
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
logger.info('Found {:d}/{:d} matches.'.format(obiwan['MATCHED'].sum(),obiwan.size))

mask_i = obiwan.mask_maskbit(key_nobs='INPUT_NOBS',key_maskbits='INPUT_MASKBITS')
mask_o = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')
#mask_i[:] = True
#mask_o[:] = True
mask_o = mask_o & obiwan['MATCHED']

#for b in ['G','R','Z']:
    #mask = obiwan['NOBS_%s' % b] != 0
    #print((obiwan['NOBS_%s' % b][mask] != obiwan['INPUT_NOBS_%s' % b][mask]).sum())
    #plt.scatter(obiwan['EBV'][mask],obiwan['NOBS_%s' % b][mask] - obiwan['SIM_NOBS_%s' % b][mask])
    #plt.show()

oh = plt.hist(obiwan['INPUT_EBV'][mask_o],range=(0,.15),bins=10)
ih = plt.hist(obiwan['INPUT_EBV'][mask_i],range=(0,.15),bins=10)
plt.clf()
plt.plot(oh[1][:-1],oh[0]/ih[0],'k-')
plt.show()
# Out:
# [ 000062.73 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000062.86 ]: 01-01 21:24  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000063.96 ]: 01-01 21:24  EBV1000         INFO     Found 117676/122881 matches.

# %%
for xlabel in ['INPUT_EBV']:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=False,figsize=(14,4))
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    bands = ['G','R','Z']
    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        obiwan['DELTAREL_FLUX_{}'.format(b)] = (obiwan['FLUX_{}'.format(b)] - obiwan['INPUT_FLUX_{}'.format(b)])*obiwan['FLUX_IVAR_{}'.format(b)]**0.5
        mask = obiwan['MATCHED']
        yerr = stats.binned_statistic(obiwan[xlabel][mask],obiwan['DELTAREL_FLUX_{}'.format(b)][mask],bins=xedges,statistic=estimate_std)[0]
        ax.plot(x,yerr)
        ax.set_xlabel(xlabel)
        ax.set_ylabel('residual dispersion')
    plt.show()

# %%
obiwan = Catalogue.load(path_obiwan)
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
logger.info('Found {:d}/{:d} matches.'.format(obiwan['MATCHED'].sum(),obiwan.size))
obiwan.set_estimated_flux(key='INPUT_EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask_tsin = obiwan.mask_maskbit(key_nobs='INPUT_NOBS',key_maskbits='INPUT_MASKBITS') & obiwan.mask_ts(key_flux='INPUT_EFLUX',region=region)
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan.mask_ts(key_flux='EFLUX',region=region) & obiwan['MATCHED']
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
from_map(obiwan,fields=['STARDENS'])
obiwan_data = obiwan[mask_tsout]
obiwan_randoms = obiwan[mask_tsin]

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
bins = np.linspace(0.5,2.5,20)
for iax,(ax,prop) in enumerate(zip(lax,props)):
    quantiles = np.quantile(obiwan_data[prop],q=np.linspace(0.,1.,3))
    cat = obiwan_data
    for iq,(low,up) in enumerate(zip(quantiles[:-1],quantiles[1:])):
        mask = (cat[prop] >= low) & (cat[prop] <= up)
        hist,edges = np.histogram(cat['INPUT_REDSHIFT'][mask],bins=bins,density=True)
        mid = (edges[:-1] + edges[1:])/2.
        ax.plot(mid,hist,label='%s #%d' % (prop,iq+1))
        #ax.hist(obiwan_data['INPUT_REDSHIFT'][mask],density=True,histtype='step',bins=bins,label='quant #%d' % (iq+1))
    ax.set_xlabel('redshift')
    ax.set_ylabel('density')
    ax.legend(loc=4)
plt.show()
# Out:
# [ 000064.59 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000064.71 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000064.83 ]: 01-01 21:24  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000066.13 ]: 01-01 21:24  EBV1000         INFO     Found 117676/122881 matches.
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in greater
# [ 000066.16 ]: 01-01 21:24  EBV1000         INFO     Selecting 17044 (output)/15046 (input) injected sources.
# [ 000066.16 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.

# %%
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan = obiwan[obiwan['MATCHED']]
counts = []
for brickname in np.unique(obiwan['BRICKNAME']):
    counts.append(np.sum(obiwan['BRICKNAME'] == brickname))
print('Number of randoms per brick:',np.min(counts),np.max(counts))
obiwan.set_estimated_flux(key='EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
mask = obiwan.mask_ts(key_flux='EFLUX')
obiwan.set_mag_from_flux(key_flux='EFLUX')
obiwan['GR'] = obiwan['G'] - obiwan['R']
obiwan['RZ'] = obiwan['R'] - obiwan['Z']
fig,ax = plt.subplots(ncols=1,nrows=1,sharex=False,sharey=False,figsize=(4,4))
ax.scatter(obiwan['RZ'],obiwan['GR'],color='b')
ax.scatter(obiwan['RZ'][mask],obiwan['GR'][mask],color='r')
ax.set_xlim(-1.,2.)
ax.set_ylim(-0.5,2.)
ax.set_xlabel('$g-r$')
ax.set_ylabel('$r-z$')
# Out:
# [ 000067.51 ]: 01-01 21:24  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000067.64 ]: 01-01 21:24  TargetSelection INFO     Selecting 122881/122881 targets.
# Number of randoms per brick: 184 344
# Text(0, 0.5, '$r-z$')

# %%
# Obiwan
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
#obiwan['MATCHED'] = obiwan['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(obiwan['MATCHED'].sum(),obiwan.size))
from_map(obiwan,fields=['STARDENS'])

gcut = 0.6
#gcut = -np.inf
gmarg = 0.; grmarg = 0.; rzmarg = 0.
#gmarg = -0.29; grmarg = -0.1; rzmarg = -0.1

def photometric_scatter(ebv,region='N',band='G'):
    ccdrms = {'N':{'G':0.016,'R':0.015,'Z':0.019}}[region][band]
    if region == 'N':
        if band in ['G','R']:
            nphotom = 2.*(4000.-1000.)/(0.15-0.025)*(ebv-0.025) + 1000.
        if band in ['Z']:
            nphotom = (1000.-250.)/(0.15-0.025)*(ebv-0.025) + 250.
    return 5.*ccdrms/(1.+ebv*100)

#bias = {'G':0.35,'R':0,'Z':0}
#bias = {'G':0.15,'R':-0.2,'Z':0}
bias = {'G':0.2,'R':0.2,'Z':0.2}
#bias = {'G':0.06,'R':-0.06,'Z':0}

for band in obiwan.bands:
    #scatter_mag = photometric_scatter(obiwan['INPUT_EBV'],region=region,band=band)
    #scatter_mag *= np.random.normal(loc=0.0,scale=1.,size=obiwan.size)
    #print(photometric_scatter(0.025,region=region,band=band))
    #obiwan['BFLUX_{}'.format(band)] = obiwan['FLUX_{}'.format(band)]*10.**(scatter_mag/(-2.5)) * 10**(-0.4*bias[band]*obiwan.EXT_COEFFS[b]*obiwan['INPUT_EBV'])
    obiwan['BFLUX_{}'.format(band)] = obiwan['FLUX_{}'.format(band)]*10**(-0.4*bias[band]*obiwan.EXT_COEFFS[band]*obiwan['INPUT_EBV'])

    
"""
from astropy.coordinates import SkyCoord
from dustmaps.sfd import SFDQuery
sfd = SFDQuery()
from dustmaps.lenz2017 import Lenz2017Query
lenz = Lenz2017Query()
"""
"""
for b in obiwan.bands:
    c = SkyCoord(ra=obiwan['RA'],dec=obiwan['DEC'],unit='deg',frame='icrs')
    #tmp = 10**(-0.4*obiwan.EXT_COEFFS[b]*(lenz(c)-sfd(c)))
    #tmp[np.isnan(tmp)] = 1.
    #obiwan['FLUX_{}'.format(b)] *= tmp
    #tmp = 10**(0.4*0.2*obiwan.EXT_COEFFS[b]*sfd(c))
    #obiwan['INPUT_FLUX_{}'.format(b)] *= tmp
    #tmp = 10**(-0.4*0.3*obiwan.EXT_COEFFS[b]*sfd(c))
    tmp = 10**(-0.4*0.25*obiwan.EXT_COEFFS[b]*obiwan['INPUT_EBV'])
    obiwan['FLUX_{}'.format(b)] *= tmp
"""

obiwan.set_estimated_flux(key='INPUT_EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask_tsin = obiwan.mask_maskbit(key_nobs='INPUT_NOBS',key_maskbits='INPUT_MASKBITS') & obiwan.mask_ts(key_flux='INPUT_EFLUX',region=region)
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan.mask_ts(key_flux='EFLUX',region=region,gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg,gcut=gcut) & obiwan['MATCHED']
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
obiwan_randoms = obiwan[mask_tsin]
obiwan_data = obiwan[mask_tsout]

obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='BFLUX')
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan.mask_ts(key_flux='EFLUX',region=region,gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg,gcut=gcut) & obiwan['MATCHED']
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
obiwan_dataebv = obiwan[mask_tsout]


# Density maps
map = Catalogue.load(path_hp)

obiwan_dens = HealpixDensity(map=map)
#obiwan_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
obiwan_dens.set_randoms(randoms=obiwan_randoms)
obiwan_dens.set_properties()
obiwan_dens.set_data(data=obiwan_data)

#obiwan_densebv = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
obiwan_densebv = HealpixDensity(map=map)
obiwan_densebv.set_randoms(randoms=obiwan_randoms)
obiwan_densebv.set_properties()
obiwan_densebv.set_data(data=obiwan_dataebv)

data = TargetSelection.load_objects(path_data,region=region)
mask = data.trues() # do not cut data on the same bricks as Obiwan
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
data.set_mag_from_flux(key_flux='EFLUX')
mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & data.mask_ts(key_flux='EFLUX',region=region,gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg,gcut=gcut)
logger.info('Selecting {:d} targets.'.format(mask.sum()))

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()
dens.set_data(data=data[mask])

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = [obiwan_dens,obiwan_densebv]
labels = ['DR9','Obiwan','Obiwan 20% EXT G']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},xedges={'quantiles':[0.02,0.98]})
plt.show()

"""
fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
bins = np.linspace(0.5,2.5,20)
for iax,(ax,prop) in enumerate(zip(lax,props)):
    quantiles = np.quantile(obiwan_data[prop],q=np.linspace(0.,1.,3))
    cat = obiwan_data
    for iq,(low,up) in enumerate(zip(quantiles[:-1],quantiles[1:])):
        mask = (cat[prop] >= low) & (cat[prop] <= up)
        hist,edges = np.histogram(cat['INPUT_REDSHIFT'][mask],bins=bins,density=True)
        mid = (edges[:-1] + edges[1:])/2.
        ax.plot(mid,hist,label='%s #%d' % (prop,iq+1))
        #ax.hist(obiwan_data['INPUT_REDSHIFT'][mask],density=True,histtype='step',bins=bins,label='quant #%d' % (iq+1))
    ax.set_xlabel('redshift')
    ax.set_ylabel('density')
    ax.legend(loc=4)
plt.show()

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
bins = np.linspace(0.5,2.5,20)
for iax,(ax,prop) in enumerate(zip(lax,props)):
    quantiles = np.quantile(obiwan_dataebv[prop],q=np.linspace(0.,1.,3))
    cat = obiwan_dataebv
    for iq,(low,up) in enumerate(zip(quantiles[:-1],quantiles[1:])):
        mask = (cat[prop] >= low) & (cat[prop] <= up)
        hist,edges = np.histogram(cat['INPUT_REDSHIFT'][mask],bins=bins,density=True)
        mid = (edges[:-1] + edges[1:])/2.
        ax.plot(mid,hist,label='%s #%d' % (prop,iq+1))
        #ax.hist(obiwan_data['INPUT_REDSHIFT'][mask],density=True,histtype='step',bins=bins,label='quant #%d' % (iq+1))
    ax.set_xlabel('redshift')
    ax.set_ylabel('density')
    ax.legend(loc=4)
plt.show()
"""
# Out:
# [ 000070.68 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000070.80 ]: 01-01 21:25  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000071.89 ]: 01-01 21:25  EBV1000         INFO     Found 117676/122881 matches.
# [ 000071.89 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in greater
# [ 000072.01 ]: 01-01 21:25  EBV1000         INFO     Selecting 6474 (output)/15046 (input) injected sources.
# [ 000072.26 ]: 01-01 21:25  EBV1000         INFO     Selecting 5615 (output)/15046 (input) injected sources.
# [ 000072.35 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.
# [ 000072.41 ]: 01-01 21:25  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000072.41 ]: 01-01 21:25  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000072.41 ]: 01-01 21:25  HealpixDensity  INFO     Found 1614 bricks with randoms.
# [ 000072.42 ]: 01-01 21:25  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000072.42 ]: 01-01 21:25  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000072.42 ]: 01-01 21:25  HealpixDensity  INFO     Found 1614 bricks with randoms.
# [ 000072.43 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/data_N_cut.fits.
# [ 000074.13 ]: 01-01 21:25  TargetSelection INFO     Selecting 3081248/3081248 targets.
# [ 000079.31 ]: 01-01 21:25  EBV1000         INFO     Selecting 802812 targets.
# [ 000079.31 ]: 01-01 21:25  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000079.54 ]: 01-01 21:25  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000079.54 ]: 01-01 21:25  HealpixDensity  INFO     Found 97884 bricks with randoms.
# [ 000080.76 ]: 01-01 21:25  Properties      INFO     Calculating EBV statistics.
# [ 000080.85 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0380.
# [ 000080.85 ]: 01-01 21:25  Properties      INFO     Calculating EBV statistics.
# [ 000080.91 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1255.
# [ 000080.91 ]: 01-01 21:25  Properties      INFO     Calculating EBV statistics.
# [ 000080.97 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1255.
# [ 000080.97 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000081.06 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0330.
# [ 000081.07 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000081.11 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.1161.
# [ 000081.12 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000081.16 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.1161.
# [ 000081.17 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000081.26 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0326.
# [ 000081.26 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000081.31 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0895.
# [ 000081.31 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000081.36 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0895.
# [ 000081.37 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000081.45 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0350.
# [ 000081.46 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000081.50 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0661.
# [ 000081.50 ]: 01-01 21:25  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000081.55 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0661.
# [ 000081.56 ]: 01-01 21:25  Properties      INFO     Calculating STARDENS statistics.
# [ 000081.63 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0356.
# [ 000081.64 ]: 01-01 21:25  Properties      INFO     Calculating STARDENS statistics.
# [ 000081.68 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0546.
# [ 000081.69 ]: 01-01 21:25  Properties      INFO     Calculating STARDENS statistics.
# [ 000081.73 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0546.
# [ 000081.74 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000081.83 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0363.
# [ 000081.83 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000081.88 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0495.
# [ 000081.88 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000081.93 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0495.
# [ 000081.93 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000082.02 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0375.
# [ 000082.03 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000082.08 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0502.
# [ 000082.08 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000082.12 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0502.
# [ 000082.13 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000082.21 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0368.
# [ 000082.22 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000082.26 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0389.
# [ 000082.26 ]: 01-01 21:25  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000082.31 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0389.
# "\nfig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))\nfig.subplots_adjust(hspace=0.4,wspace=0.2)\nlax = lax.flatten()\nbins = np.linspace(0.5,2.5,20)\nfor iax,(ax,prop) in enumerate(zip(lax,props)):\n    quantiles = np.quantile(obiwan_data[prop],q=np.linspace(0.,1.,3))\n    cat = obiwan_data\n    for iq,(low,up) in enumerate(zip(quantiles[:-1],quantiles[1:])):\n        mask = (cat[prop] >= low) & (cat[prop] <= up)\n        hist,edges = np.histogram(cat['INPUT_REDSHIFT'][mask],bins=bins,density=True)\n        mid = (edges[:-1] + edges[1:])/2.\n        ax.plot(mid,hist,label='%s #%d' % (prop,iq+1))\n        #ax.hist(obiwan_data['INPUT_REDSHIFT'][mask],density=True,histtype='step',bins=bins,label='quant #%d' % (iq+1))\n    ax.set_xlabel('redshift')\n    ax.set_ylabel('density')\n    ax.legend(loc=4)\nplt.show()\n\nfig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))\nfig.subplots_adjust(hspace=0.4,wspace=0.2)\nlax = lax.flatten()\nbins = np.linspace(0.5,2.5,20)\nfor iax,(ax,prop) in enumerate(zip(lax,props)):\n    quantiles = np.quantile(obiwan_dataebv[prop],q=np.linspace(0.,1.,3))\n    cat = obiwan_dataebv\n    for iq,(low,up) in enumerate(zip(quantiles[:-1],quantiles[1:])):\n        mask = (cat[prop] >= low) & (cat[prop] <= up)\n        hist,edges = np.histogram(cat['INPUT_REDSHIFT'][mask],bins=bins,density=True)\n        mid = (edges[:-1] + edges[1:])/2.\n        ax.plot(mid,hist,label='%s #%d' % (prop,iq+1))\n        #ax.hist(obiwan_data['INPUT_REDSHIFT'][mask],density=True,histtype='step',bins=bins,label='quant #%d' % (iq+1))\n    ax.set_xlabel('redshift')\n    ax.set_ylabel('density')\n    ax.legend(loc=4)\nplt.show()\n"

# %%
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
obiwan = obiwan[obiwan['MATCHED']]

fields = ['PSFDEPTH_G','PSFDEPTH_R','PSFDEPTH_Z']
cat = randoms
depth = {}
for xlabel in ['EBV']:
    fig,lax = plt.subplots(ncols=len(fields),nrows=1,sharex=False,sharey=False,figsize=(len(fields)*5,4),squeeze=False)
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    for iax,(ax,field) in enumerate(zip(lax,fields)):
        xedges = Binning(samples=cat[xlabel],quantiles=[0.03,0.99]).edges
        #xedges = np.linspace(0.03,0.15,10)
        x = (xedges[:-1] + xedges[1:])/2.
        y = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic='median')[0]
        yerr = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic=estimate_std)[0]
        counts = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic='count')[0]
        ax.errorbar(x,y/norm,yerr/norm/counts**0.5)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(field)
        depth[field] = (x,y)
    plt.show()

#fields = ['PSFDEPTH_G','PSFDEPTH_R','PSFDEPTH_Z']

for b in obiwan.bands:
    obiwan['BIAS_FLUX_{}'.format(b)] = obiwan['FLUX_{}'.format(b)]-obiwan['INPUT_FLUX_{}'.format(b)]

#fields = ['FLUX_G','FLUX_R','FLUX_Z']
fields = ['BIAS_FLUX_{}'.format(b) for b in obiwan.bands]
cat = obiwan
#for xlabel in ['EBV']:
for xlabel in fields:
    fig,lax = plt.subplots(ncols=len(fields),nrows=1,sharex=False,sharey=False,figsize=(len(fields)*5,4),squeeze=False)
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    for iax,(ax,field) in enumerate(zip(lax,fields)):
        xedges = Binning(samples=cat[xlabel],quantiles=[0.03,0.99]).edges
        #xedges = np.linspace(0.03,0.15,10)
        x = (xedges[:-1] + xedges[1:])/2.
        y = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic='median')[0]
        yerr = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic=estimate_std)[0]
        counts = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic='count')[0]
        ax.errorbar(x,y/norm,yerr/norm/counts**0.5)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(field)
    plt.show()
# Out:
# [ 000083.21 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000083.33 ]: 01-01 21:25  TargetSelection INFO     Selecting 122881/122881 targets.

# %%
for xlabel in ['BIAS_FLUX_{}'.format(b) for b in obiwan.bands]:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=False,figsize=(16,6))
    fig.subplots_adjust(hspace=0.4,wspace=0.4)
    lax = lax.flatten()
    for ax,b in zip(lax,obiwan.bands):
        field = 'BIAS_FLUX_{}'.format(b)
        obiwan.plot_scatter(ax,prop1=xlabel,prop2=field,xedges={'quantiles':[0.01,0.99]},yedges={'quantiles':[0.01,0.99]})
        mask = (np.abs(cat[xlabel]) < 0.3) & (np.abs(cat[field]) < 0.3)
        print(xlabel,field,'correlation',np.corrcoef(cat[xlabel][mask],cat[field][mask])[0,1])
    plt.show()
# Out:
# BIAS_FLUX_G BIAS_FLUX_G correlation 1.0
# BIAS_FLUX_G BIAS_FLUX_R correlation 0.36364223621435565
# BIAS_FLUX_G BIAS_FLUX_Z correlation 0.12448627245689477
# BIAS_FLUX_R BIAS_FLUX_G correlation 0.3636422362143557
# BIAS_FLUX_R BIAS_FLUX_R correlation 1.0
# BIAS_FLUX_R BIAS_FLUX_Z correlation 0.11873730506058362
# BIAS_FLUX_Z BIAS_FLUX_G correlation 0.12448627245689477
# BIAS_FLUX_Z BIAS_FLUX_R correlation 0.11873730506058361
# BIAS_FLUX_Z BIAS_FLUX_Z correlation 1.0

# %% [markdown]
# # Let's try to reproduce Obiwan results with MCtool

# %%
from photometry import *

fields_depth = ['PSFDEPTH_G','PSFDEPTH_R','PSFDEPTH_Z']
cat = randoms
depth = {}
for xlabel in ['EBV']:
    fig,lax = plt.subplots(ncols=len(fields_depth),nrows=1,sharex=False,sharey=False,figsize=(len(fields_depth)*5,4),squeeze=False)
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    for iax,(ax,field) in enumerate(zip(lax,fields_depth)):
        xedges = Binning(samples=cat[xlabel],quantiles=[0.03,0.99]).edges
        #xedges = np.linspace(0.03,0.15,10)
        x = (xedges[:-1] + xedges[1:])/2.
        y = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic='median')[0]
        yerr = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic=estimate_std)[0]
        counts = stats.binned_statistic(cat[xlabel],cat[field],bins=xedges,statistic='count')[0]
        ax.errorbar(x,y/norm,yerr/norm/counts**0.5)
        ax.set_xlabel(xlabel)
        ax.set_ylabel(field)
        depth[field] = (x,y)
    #plt.show()
    
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
obiwan = obiwan[obiwan['MATCHED']]

fluxbias = {}
for xlabel in ['EBV']:
    fig,lax = plt.subplots(ncols=3,nrows=2,sharex=False,sharey=False,figsize=(16,6))
    fig.subplots_adjust(hspace=0.4,wspace=0.4)
    lax = lax.flatten()
    bands = ['G','R','Z']
    for ax,b in zip(lax,bands):
        obiwan['DELTA_FLUX_{}'.format(b)] = (obiwan['FLUX_{}'.format(b)]-obiwan['INPUT_FLUX_{}'.format(b)]) #/obiwan['MW_TRANSMISSION_{}'.format(b)]
        obiwan.plot_scatter(ax,prop1=xlabel,prop2='DELTA_FLUX_{}'.format(b),xedges={'quantiles':[0.01,0.99]},yedges={'quantiles':[0.01,0.99]})
        ax.axhline(y=0,xmin=0,xmax=1,color='r')
    lax = lax[len(bands):]
    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        y = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_FLUX_{}'.format(b)],bins=xedges,statistic='median')[0]
        yerr = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_FLUX_{}'.format(b)],bins=xedges,statistic=estimate_std)[0]
        counts = stats.binned_statistic(obiwan[xlabel],obiwan['DELTA_FLUX_{}'.format(b)],bins=xedges,statistic='count')[0]
        yerr *= 1/counts**0.5
        ax.errorbar(x,y,yerr)
        ax.axhline(y=0,xmin=0,xmax=1,color='r')
        ax.set_ylabel('DELTA_FLUX_{}'.format(b))
        ax.set_xlabel(xlabel)
        fluxbias[b] = (x,y)

dispcorr = {}
for xlabel in ['INPUT_EBV']:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=False,figsize=(14,4))
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    bands = ['G','R','Z']
    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        obiwan['DELTAREL_FLUX_{}'.format(b)] = (obiwan['FLUX_{}'.format(b)] - obiwan['INPUT_FLUX_{}'.format(b)])*obiwan['FLUX_IVAR_{}'.format(b)]**0.5
        yerr = stats.binned_statistic(obiwan[xlabel],obiwan['DELTAREL_FLUX_{}'.format(b)],bins=xedges,statistic=estimate_std)[0]
        ax.plot(x,yerr)
        ax.set_xlabel(xlabel)
        ax.set_ylabel('residual dispersion')
        dispcorr[b] = (x,yerr)

dispabs = {}
for xlabel in ['INPUT_EBV']:
    fig,lax = plt.subplots(ncols=3,nrows=1,sharex=False,sharey=False,figsize=(14,4))
    fig.subplots_adjust(hspace=0.4,wspace=0.5)
    lax = lax.flatten()
    bands = ['G','R','Z']
    for ax,b in zip(lax,bands):
        xedges = Binning(samples=obiwan[xlabel],quantiles=[0.01,0.99]).edges
        x = (xedges[:-1] + xedges[1:])/2.
        obiwan['DELTAREL_FLUX_{}'.format(b)] = (obiwan['FLUX_{}'.format(b)] - obiwan['INPUT_FLUX_{}'.format(b)])
        yerr = stats.binned_statistic(obiwan[xlabel],obiwan['DELTAREL_FLUX_{}'.format(b)],bins=xedges,statistic=estimate_std)[0]
        ax.plot(x,yerr)
        ax.set_xlabel(xlabel)
        ax.set_ylabel('residual dispersion')
        dispabs[b] = (x,yerr)

#gcut = 0.9
gcut = -np.inf
dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms)
dens.set_properties()

data = TargetSelection.load_objects(path_data,region=region)
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask = data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & data.mask_ts(key_flux='EFLUX',region=region)
logger.info('Selecting {:d} targets.'.format(mask.sum()))
dens.set_data(data=data[mask])

fig,ax = plt.subplots(ncols=1,nrows=1,sharex=False,sharey=False,figsize=(6,6))
dens.plot_density_variations(ax=ax,others=[],prop='EBV',histos=[dens],var_kwargs={'labels':'DR9'},leg_kwargs={},xedges={'quantiles':[0.1,0.9]})
ebv = np.linspace(*ax.get_xlim(),num=10)
model = 1. - .25/.15*ebv # Ashley's fit
norm = 1.04 # just for plotting purposes
model = model/np.mean(model)/norm - 1.

truth = TargetSelection.load_objects(path_truth,tracer='ELG',region=None,case_sensitive=False)
truth.set_flux_from_mag(key='FLUX')
truth['REDSHIFT'] = truth['hsc_mizuki_photoz_best']
truth.region = region
mask = np.all([~np.isnan(truth[b]) for b in truth.bands],axis=0)
truth = truth[mask]

correlation = np.ones((3,3))*0.2 #just give them all correlation of 0.5 for now
correlation[0,1] = correlation[1,0] = 0.5
np.fill_diagonal(correlation,1.)

efficiency = []
#bias = {'G':0.10,'R':0.10,'Z':0.10}
bias = {'G':0.20,'R':0.20,'Z':0.20}
for ebv_ in ebv:
    mc = MCTool(truth=truth,seed=42)
    mc.set_sel_params(sn_band_min=6,sn_flat_min=None,sn_red_min=None)
    #std_scaling = np.array([np.interp(ebv_,dispcorr[b][0],dispcorr[b][1]) for b in obiwan.bands]) 
    #std = std_scaling*np.array([np.interp(ebv_,depth[field][0],depth[field][1])**(-0.5) for field in fields_depth])
    #std = np.array([np.interp(ebv_,dispabs[b][0],dispabs[b][1]) for b in obiwan.bands])
    std = np.array([np.mean(dispabs[b][1]) for b in obiwan.bands])
    #std *= (0.9*(ebv_-0.02)/(0.15-0.02) + 1)
    #std *= (-0.4*(ebv_-0.15)/(0.15-0.02) + 1)*2
    flux_covariance = correlation*std*std[:,None]
    flux_bias = np.array([np.interp(ebv_,fluxbias[b][0],fluxbias[b][1]) for b in obiwan.bands]) 
    #flux_bias[:] = 0
    mc.set_sim_params(flux_covariance=flux_covariance,flux_adbias=flux_bias,flux_mulbias=1.)
    mc.sim['EBV'] = ebv_
    mc.sim.set_estimated_transmission(key='EMW_TRANSMISSION')
    mc.sim.set_estimated_transmission(key='MW_TRANSMISSION')
    #mc.sim['MW_TRANSMISSION_G'] *= predict_additional_transmission(ebv=mc.sim['EBV'],flux=mc.truth['FLUX_G'],b='G')
    for band in mc.sim.bands:
        mc.sim['EMW_TRANSMISSION_{}'.format(band)] *= 10**(0.4*bias[band]*mc.sim.EXT_COEFFS[band]*mc.sim['EBV'])
    mc()
    efficiency.append(mc.get_efficiency())

efficiency = np.array(efficiency)/np.mean(efficiency)/norm - 1.

ax.plot(ebv,model,label='empirical fit',color='k')
ax.plot(ebv,efficiency,label='MC prediction',color='r')

ax.legend()
plt.show()
# Out:
# [ 000098.42 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000098.54 ]: 01-01 21:25  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000100.99 ]: 01-01 21:25  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000101.21 ]: 01-01 21:25  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000101.22 ]: 01-01 21:25  HealpixDensity  INFO     Found 97884 bricks with randoms.
# [ 000101.22 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/data_N_cut.fits.
# [ 000102.25 ]: 01-01 21:25  TargetSelection INFO     Selecting 3081248/3081248 targets.
# [ 000108.42 ]: 01-01 21:25  EBV1000         INFO     Selecting 2382221 targets.
# [ 000109.48 ]: 01-01 21:25  Properties      INFO     Calculating EBV statistics.
# [ 000109.57 ]: 01-01 21:25  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1960.
# [ 000109.58 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/desi_mcsyst_truth.dr7.34ra38.-7dec-3.fits.
# [ 000109.67 ]: 01-01 21:25  TargetSelection INFO     Selecting 549181/549181 targets.

# %% [markdown]
# # Let's look at data v.s. Obiwan mag and color distribution

# %%
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
from_map(obiwan,fields=['STARDENS'])

bias = {'G':0.20,'R':0.20,'Z':0.20}
for band in obiwan.bands:
    obiwan['BFLUX_{}'.format(band)] = obiwan['FLUX_{}'.format(band)]*10**(-0.4*bias[band]*obiwan.EXT_COEFFS[band]*obiwan['INPUT_EBV'])

obiwan.set_estimated_flux(key='INPUT_EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
mask_tsin = obiwan.mask_maskbit(key_nobs='INPUT_NOBS',key_maskbits='INPUT_MASKBITS') & obiwan.mask_ts(key_flux='INPUT_EFLUX',region=region)
obiwan_randoms = obiwan[mask_tsin]

obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan.mask_ts(key_flux='EFLUX',region=region) & obiwan['MATCHED']
obiwan_data = obiwan[mask_tsout]

obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='BFLUX')
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan.mask_ts(key_flux='EFLUX',region=region) & obiwan['MATCHED']
obiwan_dataebv = obiwan[mask_tsout]
for b in obiwan.bands: obiwan_dataebv['FLUX_{}'.format(b)] = obiwan_dataebv['FLUX_{}'.format(b)]

#obiwan_data = obiwan[obiwan['MATCHED']]

# ELG targets, TS applied already
bricknames = np.unique(obiwan['BRICKNAME'])
data = TargetSelection.load_objects(path_data,region=region)
mask = np.in1d(data['BRICKNAME'],bricknames)
#mask[:] = True # do not cut data on the same bricks as Obiwan
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & data.mask_ts(key_flux='EFLUX',region=region)
logger.info('Selecting {:d} targets.'.format(mask.sum()))
data = data[mask]

prop = 'EBV'
quantiles = np.quantile(obiwan_data[prop],q=np.linspace(0.,1.,4))
quantiles = list(zip(quantiles[:-1],quantiles[1:]))

cats = [data,obiwan_data,obiwan_dataebv]
titles = ['DR9','Obiwan','Obiwan -20% EBV']
fields = ['G','R','Z','G-R','R-Z']
for cat in cats:
    cat.set_mag_from_flux(key_flux='EFLUX')
    cat['G-R'] = cat['G'] - cat['R']
    cat['R-Z'] = cat['R'] - cat['Z']

fig,lax = plt.subplots(ncols=len(fields),nrows=len(cats),sharex=False,sharey=True,figsize=(4*len(fields),4*len(cats)))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
for ifield,(field,laxf) in enumerate(zip(fields,lax.T)):
    edges = Binning(samples=data[field],quantiles=[0.001,0.999],nbins=15).edges
    for iax,(ax,cat,title) in enumerate(zip(laxf,cats,titles)):
        for iq,(low,up) in enumerate(quantiles):
            mask = (cat[prop] >= low) & (cat[prop] <= up)
            hist,edges = np.histogram(cat[field][mask],bins=edges,density=True)
            mid = (edges[:-1] + edges[1:])/2.
            ax.plot(mid,hist,label='%s #%d' % (prop,iq+1),linestyle='-')
        ax.set_xlabel(field)
        ax.set_ylabel('density')
        ax.set_title(title)
        if ifield == 0: ax.legend(loc=2)
plt.show()
# Out:
# [ 000114.38 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000114.59 ]: 01-01 21:25  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000115.85 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in greater
# [ 000116.68 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/data_N_cut.fits.
# [ 000117.49 ]: 01-01 21:25  TargetSelection INFO     Selecting 3081248/3081248 targets.
# [ 000122.20 ]: 01-01 21:25  EBV1000         INFO     Selecting 10823 targets.

# %%
# Obiwan
obiwan = TargetSelection.load_objects(path_obiwan,radecbox=None,tracer='ELG',region=None)
obiwan.set_upper_case()
obiwan['RA'] = obiwan['INPUT_RA']
obiwan['DEC'] = obiwan['INPUT_DEC']
#obiwan['MATCHED'] = obiwan['DISTANCE'] < 0.15/3600.
logger.info('Found {:d}/{:d} matches.'.format(obiwan['MATCHED'].sum(),obiwan.size))
from_map(obiwan,fields=['STARDENS'])

#gcut = 0.8
gcut = -np.inf
#gmarg = 0.; grmarg = 0.; rzmarg = 0.
gmarg = -0.29; grmarg = -0.1; rzmarg = -0.1

#bias = {'G':0.35,'R':0,'Z':0}
#bias = {'G':0.15,'R':-0.2,'Z':0}
#bias = {'G':0.2,'R':0.2,'Z':0.2}
if run == 'south':
    #bias = {'G':-0.1,'R':-0.1,'Z':-0.1}
    bias = {'G':0.,'R':0.,'Z':0.}
else:
    bias = {'G':0.15,'R':0.15,'Z':0.15}
#bias = {'G':0.06,'R':-0.06,'Z':0}

obiwan.set_estimated_flux(key='INPUT_EFLUX',key_transmission='INPUT_MW_TRANSMISSION',key_flux='INPUT_FLUX')
obiwan.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
mask_tsin = obiwan.mask_maskbit(key_nobs='INPUT_NOBS',key_maskbits='INPUT_MASKBITS') & obiwan.mask_ts(key_flux='INPUT_EFLUX',region=region)
mask_tsout = obiwan.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & obiwan.mask_ts(key_flux='EFLUX',region=region,gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg,gcut=gcut) & obiwan['MATCHED']
logger.info('Selecting {:d} (output)/{:d} (input) injected sources.'.format(mask_tsout.sum(),mask_tsin.sum()))
obiwan_randoms = obiwan[mask_tsin]
obiwan_data = obiwan[mask_tsout]


# Density maps
map = Catalogue.load(path_hp)

obiwan_dens = HealpixDensity(map=map)
#obiwan_dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
obiwan_dens.set_randoms(randoms=obiwan_randoms)
obiwan_dens.set_properties()
obiwan_dens.set_data(data=obiwan_data)

#obiwan_densebv = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
obiwan_densebv = HealpixDensity(map=map)
obiwan_densebv.set_randoms(randoms=obiwan_randoms)
obiwan_densebv.set_properties()
obiwan_densebv.set_data(data=obiwan_dataebv)

data = TargetSelection.load_objects(path_data,region=region)
mask_data = np.in1d(data['BRICKNAME'],bricknames)
mask_data[:] = True # do not cut data on the same bricks as Obiwan
data.set_estimated_flux(key='EFLUX',key_transmission='MW_TRANSMISSION',key_flux='FLUX')
for band in data.bands: data['EFLUX_{}'.format(band)] /= 10**(-0.4*bias[band]*data.EXT_COEFFS[band]*data['EBV']) 
data.set_mag_from_flux(key_flux='EFLUX')
mask_data &= data.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS') & data.mask_ts(key_flux='EFLUX',region=region,gmarg=gmarg,grmarg=grmarg,rzmarg=rzmarg,gcut=gcut)
logger.info('Selecting {:d} targets.'.format(mask.sum()))

randoms = TargetSelection.load_objects(path_randoms,region=region)
mask_randoms = np.in1d(randoms['BRICKNAME'],bricknames)
mask_randoms[:] = True
mask_randoms &= randoms.mask_maskbit(key_nobs='NOBS',key_maskbits='MASKBITS')

dens = HealpixDensity(map=map)
#dens = BinnedDensity(ref=randoms,fields=['EBV'],nbins=100,ranges=[0.01,0.14])
dens.set_randoms(randoms=randoms[mask_randoms])
dens.set_properties()
dens.set_data(data=data[mask_data])

props = ['EBV'] + ['GALDEPTH_{}'.format(b) for b in data.bands] + ['STARDENS'] + ['PSFSIZE_{}'.format(b) for b in data.bands]

others = [obiwan_dens]
labels = ['DR9','Obiwan']

fig,lax = plt.subplots(ncols=4,nrows=2,sharex=False,sharey=True,figsize=(16,6))
fig.subplots_adjust(hspace=0.4,wspace=0.2)
lax = lax.flatten()
for iax,prop in enumerate(props):
    dens.plot_density_variations(ax=lax[iax],others=others,prop=prop,histos=[dens],var_kwargs={'labels':labels if iax==0 else None},leg_kwargs={},xedges={'quantiles':[0.02,0.98]})
plt.show()
# Out:
# [ 000124.28 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/Obiwan/dr9/ebv1000/north/merged/matched_input.fits.
# [ 000124.40 ]: 01-01 21:25  TargetSelection INFO     Selecting 122881/122881 targets.
# [ 000125.77 ]: 01-01 21:25  EBV1000         INFO     Found 117676/122881 matches.
# [ 000125.77 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in greater
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in less
# /home/adematti/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: invalid value encountered in greater
# [ 000125.85 ]: 01-01 21:25  EBV1000         INFO     Selecting 6595 (output)/15046 (input) injected sources.
# [ 000126.09 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/pixweight.fits.
# [ 000126.14 ]: 01-01 21:25  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000126.15 ]: 01-01 21:25  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000126.15 ]: 01-01 21:25  HealpixDensity  INFO     Found 1614 bricks with randoms.
# [ 000126.16 ]: 01-01 21:25  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000126.16 ]: 01-01 21:25  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000126.16 ]: 01-01 21:25  HealpixDensity  INFO     Found 1614 bricks with randoms.
# [ 000126.17 ]: 01-01 21:25  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/data_N_cut.fits.
# [ 000127.00 ]: 01-01 21:25  TargetSelection INFO     Selecting 3081248/3081248 targets.
# [ 000133.08 ]: 01-01 21:26  EBV1000         INFO     Selecting 4693 targets.
# [ 000133.08 ]: 01-01 21:26  Catalogue       INFO     Loading catalogue /home/adematti/Bureau/DESI/targets_ELG_dr9m/randoms_N_cut.fits.
# [ 000135.70 ]: 01-01 21:26  TargetSelection INFO     Selecting 3222451/3222451 targets.
# [ 000156.58 ]: 01-01 21:26  HealpixDensity  INFO     Found in header (nside,nest) = (256,True).
# [ 000158.14 ]: 01-01 21:26  HealpixDensity  INFO     Inferring brickid from randoms.
# [ 000158.14 ]: 01-01 21:26  HealpixDensity  INFO     Found 97884 bricks with randoms.
# [ 000159.39 ]: 01-01 21:26  Properties      INFO     Calculating EBV statistics.
# [ 000159.49 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.0380.
# [ 000159.50 ]: 01-01 21:26  Properties      INFO     Calculating EBV statistics.
# [ 000159.55 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in EBV plot: 0.1255.
# [ 000159.56 ]: 01-01 21:26  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000159.65 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.0330.
# [ 000159.65 ]: 01-01 21:26  Properties      INFO     Calculating GALDEPTH_G statistics.
# [ 000159.69 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_G plot: 0.1161.
# [ 000159.70 ]: 01-01 21:26  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000159.79 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0326.
# [ 000159.79 ]: 01-01 21:26  Properties      INFO     Calculating GALDEPTH_R statistics.
# [ 000159.84 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_R plot: 0.0895.
# [ 000159.85 ]: 01-01 21:26  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000159.93 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0350.
# [ 000159.94 ]: 01-01 21:26  Properties      INFO     Calculating GALDEPTH_Z statistics.
# [ 000159.98 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in GALDEPTH_Z plot: 0.0661.
# [ 000159.99 ]: 01-01 21:26  Properties      INFO     Calculating STARDENS statistics.
# [ 000160.07 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0356.
# [ 000160.07 ]: 01-01 21:26  Properties      INFO     Calculating STARDENS statistics.
# [ 000160.11 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in STARDENS plot: 0.0546.
# [ 000160.12 ]: 01-01 21:26  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000160.20 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0363.
# [ 000160.21 ]: 01-01 21:26  Properties      INFO     Calculating PSFSIZE_G statistics.
# [ 000160.25 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_G plot: 0.0495.
# [ 000160.25 ]: 01-01 21:26  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000160.34 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0375.
# [ 000160.35 ]: 01-01 21:26  Properties      INFO     Calculating PSFSIZE_R statistics.
# [ 000160.39 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_R plot: 0.0502.
# [ 000160.40 ]: 01-01 21:26  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000160.49 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0368.
# [ 000160.49 ]: 01-01 21:26  Properties      INFO     Calculating PSFSIZE_Z statistics.
# [ 000160.54 ]: 01-01 21:26  HealpixDensity  INFO     Fraction of randoms not included in PSFSIZE_Z plot: 0.0389.
